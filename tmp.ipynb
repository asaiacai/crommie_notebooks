# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl 
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.animation import FuncAnimation

# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 5))
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience
import os
import seaborn as sns
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')
import pims
import pySPM as spm 
import trackpy as tp
import glob
from sxmreader import SXMReader
# Out:
# /home/a/as/asai/dsgo/trading/trading/lib/python3.5/site-packages/pySPM/utils/misc.py:135: UserWarning: the library tqdm cannot be found. All progressbar will be disabled.
#   warn("the library tqdm cannot be found. All progressbar will be disabled.")

# %%
START = 51
SIZE = 4
n_range = range(START, START + SIZE)
N = len(n_range)
SXM_PATH = ["electromigration_18/Image_{0:03}.sxm".format(i) for i in n_range]
frames = SXMReader(SXM_PATH)
molecule_size = 9
min_mass = 2
max_mass = 8
min_size = 0.5
max_ecc = 1
separation = 7
searchRange = 25
adaptive_stop = 5
# frames[0] = frames[0][::-1]

# %%
SXM_PATH
# Out:
# ['electromigration_18/Image_051.sxm',
#  'electromigration_18/Image_052.sxm',
#  'electromigration_18/Image_053.sxm',
#  'electromigration_18/Image_054.sxm']

# %%
# f = tp.batch(frames[:], molecule_size, minmass=min_mass, separation=separation)
f = tp.find_link(frames[:], 5, 10, diameter=5)
plt.figure()

fig=plt.figure(figsize=(4, 3))
ax1=plt.axes(xlim=(0, 256), ylim=(0, 256), frameon=False)
ln, = ax1.plot([], [], lw=3)
plt.axis('off')

def update(i):
    tp.annotate(f[f['frame']==i], frames[i],  plot_style={'markersize': 0.5}, ax=ax1)
    for line in ax1.lines[:-1]:
        line.set_marker(None)
    return ln,

ani = FuncAnimation(fig, update, frames=range(len(frames)), interval=500)
ani
# Out:
# Frame 3: 162 trajectories present.
# <video width="288" height="216" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#t = tp.link(f, search_range=searchRange)#, adaptive_step=0.99)
t = tp.link(f, search_range=searchRange)#, adaptive_step=0.99)
plt.figure()
tp.mass_size(t.groupby('particle').mean()); # convenience function -- just plots size vs. mass
tp.mass_ecc(t.groupby('particle').mean()); # convenience function -- just plots size vs. mass
# Out:
# Frame 3: 4 trajectories present.

# %%
t1 = t[((t['mass'] > min_mass) & (t['size'] > min_size) &
         (t['ecc'] < max_ecc)) & (t['mass'] < max_mass)]
t2 = tp.filter_stubs(t, 2)
# Compare the number of particles in the unfiltered and filtered data.
print('Before:', t['particle'].nunique())
print('After:', t2['particle'].nunique())
# Out:
# Before: 25
# After: 23

# %%
plt.title("Ensemble Drift, " + SXM_PATH[0] + " to {}".format(n_range[-1]))
tp.plot_traj(t2[(t2['frame']<=3)], superimpose=frames[3], label=False)

# %%
from IPython.display import HTML
from matplotlib.animation import FuncAnimation

fig=plt.figure(figsize=(8, 6), dpi=120)
ax1=plt.axes(xlim=(0, 256), ylim=(0, 256), frameon=False)
plt.axis('on')
ln, = ax1.plot([], [], lw=3)
ax1.set_prop_cycle(color=['g', 'r', 'c', 'm', 'y', 'k'])

def update(i):
#     tp.plot_traj(t2[(t2['frame']<=i)], superimpose=frames[i], label=False, ax=ax1)
    tp.plot_traj(t2[(t2['frame']<=i)], superimpose=frames[i], label=False, ax=ax1)
    ax1.set_prop_cycle(color=['g', 'r', 'c', 'm', 'y', 'k'])
    return ln,

ani = FuncAnimation(fig, update, frames=range(len(frames)), interval=1000)
ani
# Out:
# <video width="960" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
d = tp.compute_drift(t2)
t3 = tp.subtract_drift(t2.copy(), d)
d.loc[0] = [0, 0]
# print(d)

# %%
plt.figure(figsize=(5, 5))
tp.plot_traj(t3)

# %%
drifts = []

# %%
drifts.append(d)

# %%
NM_PER_PIXEL = frames.meters_per_pixel * 1e9

# %%
plt.figure(figsize=(10, 10))
colors = ['r', 'k', 'b', 'g', 'tab:orange', 'tab:purple']
labels = [1.0]
arrs = []
j = 0
for d in drifts:
    print(_)
#     sns.scatterplot(x='x', y='y', data=d * NM_PER_PIXEL, alpha=0.0)
    for i in range(1, len(d)):
        d0, d1 = d.loc[i - 1] * NM_PER_PIXEL, d.loc[i] * NM_PER_PIXEL
        plt.arrow(d0.x,d0.y,d1.x-d0.x, d1.y-d0.y, 
        shape='full', length_includes_head=True, 
        zorder=0, head_length=1, head_width=1,)
    else:
        arrs.append(plt.arrow(d0.x,d0.y,d1.x-d0.x, d1.y-d0.y, 
        shape='full', length_includes_head=True, 
        zorder=0, head_length=1, head_width=1,))
    j += 1
new_labels, arrs = zip(*sorted(zip(labels, arrs)))
plt.legend(arrs, new_labels)
plt.title("Ensemble Drift, " + SXM_PATH[0] + " to {}".format(n_range[-1]))
plt.xlabel("x (nm)")
plt.ylabel("y (nm)")
plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.show()
# Out:
#               y          x
# frame
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# 5           NaN        NaN
# ...         ...        ...
# 96     6.016510 -15.041348
# 97     3.828700 -16.480347
# 98     0.600712 -18.540079
# 99    -2.070003 -20.880811
# 0     -4.396197 -19.869332
#
# [100 rows x 2 columns]

# %%
import scipy
endpoints = np.array([d.loc[14] * NM_PER_PIXEL for d in drifts])
mag_displace = np.linalg.norm(endpoints, 2, axis=1)
new_labels, mag_displace = zip(*sorted(zip(labels, mag_displace)))
def exponenial_func(x, a, b, c):
    return a*np.exp(-b*x)+c


popt, pcov = scipy.optimize.curve_fit(exponenial_func, new_labels, mag_displace)

xx = np.linspace(0.95, 1.2, 100)
yy = exponenial_func(xx, *popt)

plt.plot(new_labels, np.array(mag_displace) / 1.5, 'o')
plt.plot(xx, yy / 1.5)
plt.title('drift velocity')
plt.ylabel('velocity (micron / s)')
plt.xlabel('Source Drain (V)')

# %%
displacement_df = tp.relate_frames(t2, 0, 1) * NM_PER_PIXEL
for i in range(1, SIZE - 1):
    displacement_df = displacement_df.append(tp.relate_frames(t2, i, i + 1) * NM_PER_PIXEL, ignore_index=True)

# %%
displacement_df
# Out:
#              x          y        x_b        y_b        dx        dy        dr  \
# 0    75.473346   1.490502  75.633310   1.367345  0.159964 -0.123158  0.201882
# 1    78.086529  88.048207  77.104493  88.573592 -0.982036  0.525386  1.113744
# 2    24.596394  86.291147  24.580440  86.129880 -0.015954 -0.161268  0.162055
# 3    59.284806  81.260350  58.821461  81.090970 -0.463345 -0.169380  0.493334
# 4    82.708021  77.433804  82.254327  77.538341 -0.453695  0.104536  0.465582
# ..         ...        ...        ...        ...       ...       ...       ...
# 438  51.984182  35.624614  51.954274  35.608532 -0.029908 -0.016082  0.033958
# 439  22.264871  35.858664  21.457806  37.456963 -0.807065  1.598299  1.790506
# 440   9.972340  36.770245   9.828440  36.462729 -0.143900 -0.307516  0.339519
# 441  66.782942  40.716817  67.068839  40.635139  0.285897 -0.081679  0.297335
# 442  74.407475  28.645446  74.530139  28.813312  0.122664  0.167867  0.207908
#
#      direction
# 0    -0.341729
# 1     1.380386
# 2    -0.869480
# 3    -1.453710
# 4     1.518299
# ..         ...
# 438  -1.379292
# 439   1.061666
# 440  -1.046078
# 441  -0.144937
# 442   0.489452
#
# [443 rows x 8 columns]

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal', 'box')
plt.scatter(displacement_df['dx'],displacement_df['dy'])
plt.xlim(-0.5,0.5)
plt.ylim(-0.5,0.5)
plt.grid()
ax.set_aspect('equal', 'box')
plt.figure(figsize=(5,5));
plt.scatter(displacement_df['dx'],displacement_df['dy'])
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.grid()
ax.set_aspect('equal', 'box')

# %% [markdown]
# # WAIT TIME ANALYSIS

# %%
t4 = t3.drop(columns='frame').reset_index().sort_values(['particle', 'frame'])
t4['step_y'] = t4.groupby('particle').diff()['y']
t4['step_x'] = t4.groupby('particle').diff()['x']

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='step_x', y='step_y', data=t4 * NM_PER_PIXEL)
plt.xlabel("x (nm)")
plt.ylabel("y (nm)")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
# Out:
# (-10, 10)

# %%
t4[t4.particle == 2]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/dsgo/trading/trading/lib/python3.5/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    4231         try:
# -> 4232             return key in self._engine
#    4233         except (OverflowError, TypeError, ValueError):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-278-47e882a55c1c> in <module>
# ----> 1 t4[t4.particle -- 2]
#
# ~/dsgo/trading/trading/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5175             return object.__getattribute__(self, name)
#    5176         else:
# -> 5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
#    5179             return object.__getattribute__(self, name)
#
# ~/dsgo/trading/trading/lib/python3.5/site-packages/pandas/core/indexes/base.py in _can_hold_identifiers_and_holds_name(self, name)
#    4305         """
#    4306         if self.is_object() or self.is_categorical():
# -> 4307             return name in self
#    4308         return False
#    4309
#
# ~/dsgo/trading/trading/lib/python3.5/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    4231         try:
#    4232             return key in self._engine
# -> 4233         except (OverflowError, TypeError, ValueError):
#    4234             return False
#    4235
#
# KeyboardInterrupt:

# %%
t4['step_size'] = np.sqrt(t4['step_x'] ** 2 + t4['step_y'] ** 2)
t4['big_step'] = t4['step_size'] > 10
a = ~t4['big_step']
b = a.cumsum()
c = b-b.where(~a).ffill().fillna(1).astype(int)
t4['wait'] = c
t4['wait'] = t4['wait'].replace(0, np.nan).ffill(limit=1)
t4[t4['big_step']].dropna()
# Out:
#      frame           y           x      mass      size       ecc    signal  \
# 72       2  174.098734   39.690340  4.808615  1.830630  0.093042  0.369189
# 229      6  158.248674   33.150365  4.715513  1.801042  0.192747  0.374976
# 402     12  212.608462   14.802080  4.760476  1.791610  0.163146  0.374454
# 182      5  195.301694   97.477209  4.701746  1.843765  0.202021  0.366593
# 248      7  190.415212  104.189439  4.666769  1.778071  0.221526  0.375381
# ..     ...         ...         ...       ...       ...       ...       ...
# 425     13  227.315411  178.502980  4.789136  1.720998  0.055577  0.390135
# 381     11  112.923520  152.648532  4.625103  1.758631  0.238251  0.381452
# 464     14  133.032353  129.325124  4.561296  1.730998  0.146539  0.373554
# 412     12  103.788411  227.107142  4.748199  1.724852  0.143991  0.386731
# 467     14  118.642205  207.556914  4.712533  1.758803  0.229029  0.385653
#
#       raw_mass        ep  particle     step_y     step_x  step_size  big_step  \
# 72   14.487905 -1.172080         2 -10.081164   6.290360  11.882697      True
# 229  14.515177 -0.966156         2 -11.339132  -4.092308  12.054995      True
# 402  13.812615 -0.620764         2  14.306489  -0.865293  14.332632      True
# 182  20.643393  0.374027         3   9.568686   4.251453  10.470654      True
# 248  21.852424  0.314147         3  -6.905670  10.350241  12.442499      True
# ..         ...       ...       ...        ...        ...        ...       ...
# 425  29.978425  0.136142        46   0.603529 -13.413194  13.426765      True
# 381  25.724478  0.165563        47 -10.487403  13.330128  16.961071      True
# 464  25.029457  0.196148        47  10.613575 -21.625339  24.089484      True
# 412  34.964996  0.083019        48 -12.947515  -5.680163  14.138684      True
# 467  33.337065  0.098564        50 -11.400346  -3.444039  11.909211      True
#
#      wait
# 72   17.0
# 229   3.0
# 402   1.0
# 182   7.0
# 248   1.0
# ..    ...
# 425   5.0
# 381   2.0
# 464   2.0
# 412   1.0
# 467   5.0
#
# [106 rows x 15 columns]
